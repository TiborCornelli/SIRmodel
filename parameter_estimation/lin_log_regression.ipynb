# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("data/data.csv")
df = df[df.countriesAndTerritories == "Germany"]
df.head()
# Out:
#          dateRep  day  month  year     cases  deaths countriesAndTerritories  \
# 7528  10/03/2022   10      3  2022  176823.0     5.0                 Germany
# 7529  09/03/2022    9      3  2022  236563.0    22.0                 Germany
# 7530  08/03/2022    8      3  2022  235748.0    23.0                 Germany
# 7531  07/03/2022    7      3  2022  160579.0    37.0                 Germany
# 7532  06/03/2022    6      3  2022   78202.0    18.0                 Germany
#
#      geoId countryterritoryCode  popData2020 continentExp
# 7528    DE                  DEU     83166711       Europe
# 7529    DE                  DEU     83166711       Europe
# 7530    DE                  DEU     83166711       Europe
# 7531    DE                  DEU     83166711       Europe
# 7532    DE                  DEU     83166711       Europe

# %%
df.dateRep = pd.to_datetime(df.dateRep, format='%d/%m/%Y')
df = df.sort_values(by="dateRep", key=pd.to_datetime)
fig = plt.figure(figsize=(16,4))
plt.plot(df.dateRep, df.cases)
